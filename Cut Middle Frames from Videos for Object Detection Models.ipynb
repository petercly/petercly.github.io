# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
import os
import cv2

# Define the input and output directories
video_dir = 'pathname'
output_dir = 'pathname'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Get a list of all video files in the directory, filter for common video extensions to be safe
video_extensions = ('.mp4', '.mov', '.avi', '.mkv')
video_files = [f for f in os.listdir(video_dir) if f.lower().endswith(video_extensions)]

if not video_files:
    print(f"No video files found in the directory: {video_dir}")
else:
    print(f"Found {len(video_files)} video clips to process.")
    
    # Process each video file
    for video_name in video_files:
        video_path = os.path.join(video_dir, video_name)
        
        # Use a more robust way to get the video title without the extension
        video_title = os.path.splitext(video_name)[0]
        
        print(f"\nProcessing video: {video_name}")
        
        # Open the video file
        cap = cv2.VideoCapture(video_path)
        
        if not cap.isOpened():
            print(f"Error: Could not open video file {video_path}. Skipping.")
            continue
            
        # Get video properties
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        if frame_count <= 3:
            print("Video is too short (<= 3 frames). Extracting all frames.")
            frames_to_extract = range(frame_count)
        else:
            # Calculate the frame number for the middle frame in the video (arbitrarily defined)
            frames_to_extract = [
                int(frame_count / 2),               # Middle frame
            ]
        
        # Loop through the calculated frame numbers and extract them
        for i, frame_number in enumerate(frames_to_extract):
            # Set the video's position to the desired frame number
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_number)
            
            # Read the frame
            ret, frame = cap.read()
            
            if ret:
                # Create the output filename
                output_filename = f"{video_title}-frame-{i+1}.jpeg"
                output_path = os.path.join(output_dir, output_filename)
                
                # Save the frame as a JPEG image
                cv2.imwrite(output_path, frame)
                print(f"  - Saved frame {i+1} (frame number {frame_number}) to: {output_path}")
            else:
                print(f"  - Warning: Could not read frame number {frame_number}. Skipping.")
        
        # Release the video capture object
        cap.release()
    
    print("\nVideo processing complete.")
# Out:
# Found 72 video clips to process.
#
# Processing video: single-small-city-bright.mp4
#   - Saved frame 1 (frame number 167) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-city-bright-frame-1.jpeg
#
# Processing video: single-small-clouds-dark.mp4
#   - Saved frame 1 (frame number 145) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-clouds-dark-frame-1.jpeg
#
# Processing video: single-small-sky-dark.mp4
#   - Saved frame 1 (frame number 162) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-sky-dark-frame-1.jpeg
#
# Processing video: single-large-city-bright.mp4
#   - Saved frame 1 (frame number 132) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-city-bright-frame-1.jpeg
#
# Processing video: single-small-sky-bright-2.mp4
#   - Saved frame 1 (frame number 193) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-sky-bright-2-frame-1.jpeg
#
# Processing video: single-medium-ground-bright.mp4
#   - Saved frame 1 (frame number 53) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-bright-frame-1.jpeg
#
# Processing video: multiple-small-sky-dark.mp4
#   - Saved frame 1 (frame number 35) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-sky-dark-frame-1.jpeg
#
# Processing video: multiple-small-ground-dark.mp4
#   - Saved frame 1 (frame number 155) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-ground-dark-frame-1.jpeg
#
# Processing video: single-large-trees-dark.mp4
#   - Saved frame 1 (frame number 280) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-trees-dark-frame-1.jpeg
#
# Processing video: single-medium-sky-bright.mp4
#   - Saved frame 1 (frame number 70) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-sky-bright-frame-1.jpeg
#
# Processing video: single-large-trees-bright.mp4
#   - Saved frame 1 (frame number 179) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-trees-bright-frame-1.jpeg
#
# Processing video: single-small-city-bright-2.mp4
#   - Saved frame 1 (frame number 22) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-city-bright-2-frame-1.jpeg
#
# Processing video: single-small-ground-bright-2.mp4
#   - Saved frame 1 (frame number 394) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-ground-bright-2-frame-1.jpeg
#
# Processing video: single-small-ground-bright-3.mp4
#   - Saved frame 1 (frame number 109) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-ground-bright-3-frame-1.jpeg
#
# Processing video: multiple-small-field-bright.mp4
#   - Saved frame 1 (frame number 403) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-field-bright-frame-1.jpeg
#
# Processing video: single-medium-clouds-dark.mp4
#   - Saved frame 1 (frame number 447) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-clouds-dark-frame-1.jpeg
#
# Processing video: single-large-ground-dark-2.mp4
#   - Saved frame 1 (frame number 466) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-dark-2-frame-1.jpeg
#
# Processing video: single-medium-trees-bright-2.mp4
#   - Saved frame 1 (frame number 333) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-trees-bright-2-frame-1.jpeg
#
# Processing video: single-small-trees-dark-4.mp4
#   - Saved frame 1 (frame number 35) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-trees-dark-4-frame-1.jpeg
#
# Processing video: single-small-trees-dark-5.mp4
#   - Saved frame 1 (frame number 113) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-trees-dark-5-frame-1.jpeg
#
# Processing video: single-small-sky-bright.mp4
#   - Saved frame 1 (frame number 44) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-sky-bright-frame-1.jpeg
#
# Processing video: single-medium-sky-bright-2.mp4
#   - Saved frame 1 (frame number 340) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-sky-bright-2-frame-1.jpeg
#
# Processing video: single-large-ground-dark-3.mp4
#   - Saved frame 1 (frame number 52) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-dark-3-frame-1.jpeg
#
# Processing video: single-small-ground-bright-4.mp4
#   - Saved frame 1 (frame number 61) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-ground-bright-4-frame-1.jpeg
#
# Processing video: single-small-ground-bright-5.mp4
#   - Saved frame 1 (frame number 101) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-ground-bright-5-frame-1.jpeg
#
# Processing video: single-large-sky-dark.mp4
#   - Saved frame 1 (frame number 49) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-sky-dark-frame-1.jpeg
#
# Processing video: single-large-trees-bright-3.mp4
#   - Saved frame 1 (frame number 134) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-trees-bright-3-frame-1.jpeg
#
# Processing video: multiple-small-trees-bright.mp4
#   - Saved frame 1 (frame number 30) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-trees-bright-frame-1.jpeg
#
# Processing video: single-small-clouds-bright.mp4
#   - Saved frame 1 (frame number 117) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-clouds-bright-frame-1.jpeg
#
# Processing video: single-small-ground-bright.mp4
#   - Saved frame 1 (frame number 148) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-ground-bright-frame-1.jpeg
#
# Processing video: multiple-small-clouds-bright-3.mp4
#   - Saved frame 1 (frame number 268) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-clouds-bright-3-frame-1.jpeg
#
# Processing video: single-medium-ground-dark.mp4
#   - Saved frame 1 (frame number 73) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-dark-frame-1.jpeg
#
# Processing video: single-medium-ground-bright-4.mp4
#   - Saved frame 1 (frame number 16) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-bright-4-frame-1.jpeg
#
# Processing video: multiple-small-clouds-bright-2.mp4
#   - Saved frame 1 (frame number 456) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-clouds-bright-2-frame-1.jpeg
#
# Processing video: multiple-small-mountain-bright.mp4
#   - Saved frame 1 (frame number 103) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-mountain-bright-frame-1.jpeg
#
# Processing video: single-large-ground-bright-5.mp4
#   - Saved frame 1 (frame number 76) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-bright-5-frame-1.jpeg
#
# Processing video: single-large-sky-bright-3.mp4
#   - Saved frame 1 (frame number 166) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-sky-bright-3-frame-1.jpeg
#
# Processing video: single-small-trees-bright-2.mp4
#   - Saved frame 1 (frame number 136) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-trees-bright-2-frame-1.jpeg
#
# Processing video: multiple-small-sky-dark-2.mp4
#   - Saved frame 1 (frame number 36) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-sky-dark-2-frame-1.jpeg
#
# Processing video: single-small-field-bright.mp4
#   - Saved frame 1 (frame number 178) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-field-bright-frame-1.jpeg
#
# Processing video: single-large-ground-bright.mp4
#   - Saved frame 1 (frame number 312) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-bright-frame-1.jpeg
#
# Processing video: single-large-sky-bright-2.MP4
#   - Saved frame 1 (frame number 82) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-sky-bright-2-frame-1.jpeg
#
# Processing video: single-large-ground-bright-4.mp4
#   - Saved frame 1 (frame number 62) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-bright-4-frame-1.jpeg
#
# Processing video: single-medium-ground-bright-3.mp4
#   - Saved frame 1 (frame number 3) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-bright-3-frame-1.jpeg
#
# Processing video: single-medium-sky-dark.mp4
#   - Saved frame 1 (frame number 274) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-sky-dark-frame-1.jpeg
#
# Processing video: single-medium-ground-bright-2.mp4
#   - Saved frame 1 (frame number 9) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-bright-2-frame-1.jpeg
#
# Processing video: single-small-water-bright-2.mp4
#   - Saved frame 1 (frame number 158) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-water-bright-2-frame-1.jpeg
#
# Processing video: single-large-ground-bright-3.mp4
#   - Saved frame 1 (frame number 164) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-bright-3-frame-1.jpeg
#
# Processing video: single-small-indoors-bright.mp4
#   - Saved frame 1 (frame number 120) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-indoors-bright-frame-1.jpeg
#
# Processing video: single-small-trees-bright-5.mp4
#   - Saved frame 1 (frame number 23) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-trees-bright-5-frame-1.jpeg
#
# Processing video: single-large-sky-bright-4.mp4
#   - Saved frame 1 (frame number 15) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-sky-bright-4-frame-1.jpeg
#
# Processing video: single-large-ground-bright-2.mp4
#   - Saved frame 1 (frame number 118) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-bright-2-frame-1.jpeg
#
# Processing video: single-small-trees-bright.mp4
#   - Saved frame 1 (frame number 24) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-trees-bright-frame-1.jpeg
#
# Processing video: single-large-ground-dark.mp4
#   - Saved frame 1 (frame number 530) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-ground-dark-frame-1.jpeg
#
# Processing video: single-large-city-dark.mp4
#   - Saved frame 1 (frame number 56) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-city-dark-frame-1.jpeg
#
# Processing video: multiple-small-clouds-bright.mp4
#   - Saved frame 1 (frame number 346) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-clouds-bright-frame-1.jpeg
#
# Processing video: multiple-medium-sky-bright.mp4
#   - Saved frame 1 (frame number 54) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-medium-sky-bright-frame-1.jpeg
#
# Processing video: single-medium-ground-dark-2.mp4
#   - Saved frame 1 (frame number 46) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-dark-2-frame-1.jpeg
#
# Processing video: (IR) single-large-sky-dark.mp4
#   - Saved frame 1 (frame number 18) to: /Users/peterchua/Downloads/Curated Video Frames/(IR) single-large-sky-dark-frame-1.jpeg
#
# Processing video: single-small-clouds-bright-2.mp4
#   - Saved frame 1 (frame number 132) to: /Users/peterchua/Downloads/Curated Video Frames/single-small-clouds-bright-2-frame-1.jpeg
#
# Processing video: single-medium-ground-dark-3.mp4
#   - Saved frame 1 (frame number 31) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-dark-3-frame-1.jpeg
#
# Processing video: single-large-city-dark-3.mp4
#   - Saved frame 1 (frame number 73) to: /Users/peterchua/Downloads/Curated Video Frames/single-large-city-dark-3-frame-1.jpeg
#
# Processing video: multiple-small-sky-bright-2.mp4
#   - Saved frame 1 (frame number 21) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-sky-bright-2-frame-1.jpeg
#
# Processing video: single-medium-clouds-bright.mp4
#   - Saved frame 1 (frame number 923) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-clouds-bright-frame-1.jpeg
#
# Processing video: single-medium-ground-dark-6.mp4
#   - Saved frame 1 (frame number 29) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-dark-6-frame-1.jpeg
#
# Processing video: multiple-small-city-bright-2.mp4
#   - Saved frame 1 (frame number 572) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-city-bright-2-frame-1.jpeg
#
# Processing video: multiple-small-mountain-bright-2.mp4
#   - Saved frame 1 (frame number 81) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-mountain-bright-2-frame-1.jpeg
#
# Processing video: multiple-small-mountain-bright-3.mp4
#   - Saved frame 1 (frame number 98) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-mountain-bright-3-frame-1.jpeg
#
# Processing video: single-medium-trees-bright.mp4
#   - Saved frame 1 (frame number 195) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-trees-bright-frame-1.jpeg
#
# Processing video: single-medium-ground-dark-5.mp4
#   - Saved frame 1 (frame number 58) to: /Users/peterchua/Downloads/Curated Video Frames/single-medium-ground-dark-5-frame-1.jpeg
#
# Processing video: multiple-small-sky-bright-4.mp4
#   - Saved frame 1 (frame number 208) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-sky-bright-4-frame-1.jpeg
#
# Processing video: multiple-small-city-bright-3.mp4
#   - Saved frame 1 (frame number 45) to: /Users/peterchua/Downloads/Curated Video Frames/multiple-small-city-bright-3-frame-1.jpeg
#
# Video processing complete.
